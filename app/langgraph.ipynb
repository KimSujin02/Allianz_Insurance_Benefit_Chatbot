# %%
from IPython.display import Image, display
from rag_utils import CHATBOT_GRAPH

display(Image(CHATBOT_GRAPH.get_graph().draw_mermaid_png()))
# Out:
# c:\Users\Playdata\miniconda3\envs\nlp_env\Lib\site-packages\requests\__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (7.4.0.post2)/charset_normalizer (3.4.4) doesn't match a supported version!
#   warnings.warn(

# %%
from rag_utils import CHATBOT_GRAPH

png_bytes = CHATBOT_GRAPH.get_graph().draw_mermaid_png()

with open("langgraph_flow.png", "wb") as f:
    f.write(png_bytes)

print("saved: langgraph_flow.png")
